# %% [markdown]
# # Final Model Evaluation & Analysis: XGBoost
#
# After identifying that the XGBoost performed better than the Random Forest, we went about doing an extensive grid search to find the best parameters, we then did walk_forward vallidation to find the best time split.

# %%
from xgboost import XGBClassifier

best_params = {
    'n_estimators': 200,
    'max_depth': 2,
    'learning_rate': 0.05,
    'min_child_weight': 5,
    'subsample': 0.6,
    'colsample_bytree': 0.6,
    'gamma': 1,
    'reg_alpha': 2,
    'reg_lambda': 5,
    'tree_method': 'hist',
    'random_state': 1
}

model = XGBClassifier(**best_params)
