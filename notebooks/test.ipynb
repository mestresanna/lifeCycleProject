# %%
from importlib import reload
import src.preprocessing_pipeline

reload(src.preprocessing_pipeline)

from src.preprocessing_pipeline import DataPreprocessor

chosen_tickers = [
    'PETR4', 'VALE3', 'ITUB4', 'BBDC4', 'ABEV3', 'BBAS3', 'GGBR4', 'BRAP4', 'LREN3', 'MGLU3',
    'B3SA3', 'WEGE3', 'JBSS3', 'SUZB3', 'RADL3', 'ELET3', 'ELET6', 'SANB11', 'RENT3', 'RAIL3',
    'VIVT4', 'KLBN11', 'HYPE3', 'CSAN3', 'UGPA3', 'BRFS3', 'BRKM5', 'CIEL3', 'TOTS3', 'ENBR3'
]


preprocessor = DataPreprocessor(tickers=chosen_tickers)
processed_df = preprocessor.run_pipeline()
processed_df.head()
# Out:
# Loading ../data/base\2019_brazil_stocks.csv...
# Loading ../data/base\2020_brazil_stocks.csv...
# Loading ../data/base\2021_brazil_stocks.csv...
# Loading ../data/base\2022_brazil_stocks.csv...
# Loading ../data/base\2023_brazil_stocks.csv...
# [debug] Unique tickers after filter: ['ABEV3' 'B3SA3' 'BBAS3' 'BBDC4' 'BRAP4' 'BRFS3' 'BRKM5' 'CIEL3' 'CSAN3'
#  'ELET3' 'ELET6' 'ENBR3' 'GGBR4' 'HYPE3' 'ITUB4' 'JBSS3' 'KLBN11' 'LREN3'
#  'MGLU3' 'PETR4' 'RADL3' 'RAIL3' 'RENT3' 'SANB11' 'SUZB3' 'TOTS3' 'UGPA3'
#  'VALE3' 'VIVT4' 'WEGE3']
# [load_data] All chosen tickers are present in the final DataFrame.
# C:\Users\phili\OneDrive\Documentos\Philipe\Philipe\Kdg Computer Science\Third Year\Data AI 6\LifeCycleProject\src\preprocessing_pipeline.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(drop_features, axis=1, inplace=True)
# ['quantity', 'volume', 'ibovespa_close', 'day_of_week', 'price_range', 'volume_per_quantity', 'rolling_std_5', 'rolling_return_5', 'momentum_5', 'rolling_volume_5', 'Trend_2', 'Close_Ratio_5', 'Trend_5', 'Close_Ratio_55', 'Trend_55', 'Close_Ratio_220']
# Data saved successfully to ../data/2019-2023_stock_with_features_dif_tickers.csv
#            date ticker  quantity       volume ibovespa_close  day_of_week  \
# 6600 2019-11-18  ABEV3   9445200  165711710.0       106347.0            1
# 6601 2019-11-18  B3SA3  10101700  501185409.0       106347.0            1
# 6602 2019-11-18  BBAS3  15585600  724962222.0       106347.0            1
# 6603 2019-11-18  BBDC4  18808900  625495829.0       106347.0            1
# 6604 2019-11-18  BRAP4   1248000   40441499.0       106347.0            1
#
#       price_range  volume_per_quantity  tomorrow  target  rolling_std_5  \
# 6600         0.26            17.544542     17.67       1       0.091815
# 6601         1.54            49.613967     47.94       0       0.542015
# 6602         1.15            46.514874     45.79       0       0.494803
# 6603         0.91            33.255312     33.07       0       0.394373
# 6604         0.78            32.405047     32.69       1       0.455379
#
#       rolling_return_5  rolling_volume_5  momentum_5  Trend_2  Close_Ratio_5  \
# 6600          0.001866       246297201.6    0.008848      2.0       1.005843
# 6601          0.007892       394530554.4   -0.008612      1.0       0.990027
# 6602         -0.001119       641216796.2   -0.014652      1.0       0.989588
# 6603         -0.005110       597208475.0   -0.020286      0.0       0.986188
# 6604         -0.001457        46990409.6   -0.002218      2.0       1.002414
#
#       Trend_5  Close_Ratio_55  Trend_55  Close_Ratio_220
# 6600      3.0        0.946900      27.0         0.971916
# 6601      3.0        1.066652      34.0         1.284061
# 6602      2.0        0.987510      26.0         0.933396
# 6603      0.0        0.970354      27.0         0.886461
# 6604      3.0        1.032162      32.0         1.047033
