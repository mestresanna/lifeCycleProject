# %%
import yfinance as yf

# IBOVESPA ticker on Yahoo Finance
ibov = "^BVSP"

# Download 2023 data
df_ibov = yf.download(ibov, start="2023-01-01", end="2023-11-20")

# Keep only date and close
df_ibov_close = df_ibov[['Close']].reset_index()
df_ibov_close.rename(columns={'Close': 'close'}, inplace=True)

# Save locally
df_ibov_close.to_csv("../data/ibovespa_2023.csv", index=False)

print(df_ibov_close.head())
# Out:
# C:\Users\phili\AppData\Local\Temp\ipykernel_23076\4162866888.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_ibov = yf.download(ibov, start="2023-01-01", end="2023-11-20")
# [*********************100%***********************]  1 of 1 completed
# Price        Date     close
# Ticker                ^BVSP
# 0      2023-01-02  106376.0
# 1      2023-01-03  104166.0
# 2      2023-01-04  105334.0
# 3      2023-01-05  107518.0
# 4      2023-01-06  108836.0
