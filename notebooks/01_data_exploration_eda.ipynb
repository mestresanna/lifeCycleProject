# %% [markdown]
# #  1. Data Understanding and Exploration

# %% [markdown]
# ### Collect the dataset

# %% [markdown]
# This code doesn't have to be run as we didn't include the "2023_brazil_stocks.csv", since it is very big. This just shows how we extract the tickers and create the new csv.

# %%
import pandas as pd
import numpy as np
import os

# ===== Load dataset =====
#DATA_PATH = "../data/base/2023_brazil_stocks.csv"
#df = pd.read_csv(DATA_PATH)

# ===== Convert 'date' column to datetime =====
# If it's an integer like 20230102, first convert to string
#df['date'] = pd.to_datetime(df['date'].astype(str), format='%Y%m%d')

# ===== Define tickers you want to keep =====
#selected_tickers = ['PETR4', 'VALE3', 'ITUB4', 'BBDC4', 'ABEV3']

# ===== Filter dataset =====
#df_filtered = df[df['ticker'].isin(selected_tickers)]

# ===== Create output directory if it doesn't exist =====
#os.makedirs("data", exist_ok=True)

# ===== Export filtered dataset =====
#OUTPUT_PATH = "../data/2023_selected_stocks.csv"
#df_filtered.to_csv(OUTPUT_PATH, index=False)

#print(f"Filtered dataset saved to {OUTPUT_PATH}, total rows: {len(df_filtered)}")

# %%
# Explore dataset caracteristics
ds = pd.read_csv('../data/2023_selected_stocks.csv', low_memory=False)
ds.head()
# Out:
#          date ticker          name   open  close    min    max    avg  \
# 0  2023-01-02  ABEV3      AMBEVS/A  14.40  14.19  14.02  14.45  14.19
# 1  2023-01-02  BBDC4      BRADESCO  14.90  14.75  14.66  14.99  14.74
# 2  2023-01-02  ITUB4  ITAUUNIBANCO  24.43  24.49  24.04  24.53  24.26
# 3  2023-01-02  PETR4     PETROBRAS  23.54  22.92  22.80  23.81  23.09
# 4  2023-01-02  VALE3          VALE  88.68  89.40  88.53  89.90  89.42
#
#    quantity        volume currency  marketType  bdiCode prazoT  \
# 0  14995900  2.128569e+08       R$          10        2
# 1  24748300  3.650038e+08       R$          10        2
# 2  23340700  5.664208e+08       R$          10        2
# 3  78424700  1.811379e+09       R$          10        2
# 4  12783800  1.143138e+09       R$          10        2
#
#   paperSpecification  optionPrice  priceCorrection  paperDueDate  quoteFactor
# 0         ON                  0.0                0      99991231            1
# 1         PN      N1          0.0                0      99991231            1
# 2         PN  EJ  N1          0.0                0      99991231            1
# 3         PN      N2          0.0                0      99991231            1
# 4         ON      NM          0.0                0      99991231            1

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                1100 non-null   object
#  1   ticker              1100 non-null   object
#  2   name                1100 non-null   object
#  3   open                1100 non-null   float64
#  4   close               1100 non-null   float64
#  5   min                 1100 non-null   float64
#  6   max                 1100 non-null   float64
#  7   avg                 1100 non-null   float64
#  8   quantity            1100 non-null   int64
#  9   volume              1100 non-null   float64
#  10  currency            1100 non-null   object
#  11  marketType          1100 non-null   int64
#  12  bdiCode             1100 non-null   int64
#  13  prazoT              1100 non-null   object
#  14  paperSpecification  1100 non-null   object
#  15  optionPrice         1100 non-null   float64
#  16  priceCorrection     1100 non-null   int64
#  17  paperDueDate        1100 non-null   int64
#  18  quoteFactor         1100 non-null   int64
# dtypes: float64(7), int64(6), object(6)
# memory usage: 163.4+ KB

# %%
ds.describe()
# Out:
#               open        close          min          max         avg  \
# count  1100.000000  1100.000000  1100.000000  1100.000000  1100.00000
# mean     31.710518    31.693400    31.345764    32.058736    31.69240
# std      22.567197    22.519254    22.330667    22.753270    22.53171
# min      12.400000    12.290000    12.280000    12.490000    12.35000
# 25%      14.670000    14.650000    14.470000    14.840000    14.65750
# 50%      25.585000    25.620000    25.240000    25.940000    25.56500
# 75%      32.270000    32.252500    31.865000    32.547500    32.19500
# max      97.850000    98.000000    96.390000    98.290000    97.41000
#
#            quantity        volume  marketType  bdiCode  optionPrice  \
# count  1.100000e+03  1.100000e+03      1100.0   1100.0       1100.0
# mean   3.754174e+07  1.083161e+09        10.0      2.0          0.0
# std    2.305202e+07  7.811599e+08         0.0      0.0          0.0
# min    5.236900e+06  7.728633e+07        10.0      2.0          0.0
# 25%    2.262910e+07  4.818416e+08        10.0      2.0          0.0
# 50%    3.133565e+07  8.547463e+08        10.0      2.0          0.0
# 75%    4.434785e+07  1.490788e+09        10.0      2.0          0.0
# max    2.378911e+08  6.619017e+09        10.0      2.0          0.0
#
#        priceCorrection  paperDueDate  quoteFactor
# count           1100.0        1100.0       1100.0
# mean               0.0    99991231.0          1.0
# std                0.0           0.0          0.0
# min                0.0    99991231.0          1.0
# 25%                0.0    99991231.0          1.0
# 50%                0.0    99991231.0          1.0
# 75%                0.0    99991231.0          1.0
# max                0.0    99991231.0          1.0

# %%
print(ds['date'].info())

# Convert date column
ds['date'] = pd.to_datetime(ds['date'])
ds['date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 880 entries, 0 to 879
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 880 non-null    object
# dtypes: object(1)
# memory usage: 7.0+ KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 880 entries, 0 to 879
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 880 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.0 KB

# %%
print(ds['ticker'].unique())
print(ds['currency'].unique())
ds['marketType'].value_counts()
# Out:
# ['ABEV3' 'BBDC4' 'ITUB4' 'PETR4' 'VALE3']
# ['R$']
# marketType
# 10    1100
# Name: count, dtype: int64

# %%
ds.dtypes
# Out:
# date                  datetime64[ns]
# ticker                        object
# name                          object
# open                         float64
# close                        float64
# min                          float64
# max                          float64
# avg                          float64
# quantity                       int64
# volume                       float64
# currency                      object
# marketType                     int64
# bdiCode                        int64
# prazoT                        object
# paperSpecification            object
# optionPrice                  float64
# priceCorrection                int64
# paperDueDate                   int64
# quoteFactor                    int64
# dtype: object

# %%
# Check if there is any duplicates
print(ds.duplicated().any())
print(ds.duplicated().sum())
# Out:
# False
# 0

# %%
# Check how many rows in prazoT are " " to qualify if we need this column for our predictions
# Replace prazo with nan values
ds['prazoT'].str.strip().eq('').sum()
pd.set_option('future.no_silent_downcasting', True)
ds['prazoT'] = ds['prazoT'].replace(r'^\s*$', np.nan, regex=True)
ds.isna().sum()
# Out:
# date                     0
# ticker                   0
# name                     0
# open                     0
# close                    0
# min                      0
# max                      0
# avg                      0
# quantity                 0
# volume                   0
# currency                 0
# marketType               0
# bdiCode                  0
# prazoT                1100
# paperSpecification       0
# optionPrice              0
# priceCorrection          0
# paperDueDate             0
# quoteFactor              0
# dtype: int64

# %%
# Check if there is any nulls or non values in the dataset
print(ds.isnull().sum())
print(ds.isna().sum())
# Out:
# date                  0
# ticker                0
# name                  0
# open                  0
# close                 0
# min                   0
# max                   0
# avg                   0
# quantity              0
# volume                0
# currency              0
# marketType            0
# bdiCode               0
# prazoT                0
# paperSpecification    0
# optionPrice           0
# priceCorrection       0
# paperDueDate          0
# quoteFactor           0
# dtype: int64
# date                  0
# ticker                0
# name                  0
# open                  0
# close                 0
# min                   0
# max                   0
# avg                   0
# quantity              0
# volume                0
# currency              0
# marketType            0
# bdiCode               0
# prazoT                0
# paperSpecification    0
# optionPrice           0
# priceCorrection       0
# paperDueDate          0
# quoteFactor           0
# dtype: int64

# %%
# To do a fast aproach we can also explore all the unique values between the rows in each column.
ds.nunique()
# Out:
# date                   220
# ticker                   5
# name                     5
# open                   807
# close                  821
# min                    815
# max                    826
# avg                    825
# quantity              1098
# volume                1100
# currency                 1
# marketType               1
# bdiCode                  1
# prazoT                   0
# paperSpecification       9
# optionPrice              1
# priceCorrection          1
# paperDueDate             1
# quoteFactor              1
# dtype: int64

# %% [markdown]
# We can observe that the column PrazoT has definetly some empty values. It is ignoring the is null or nan because there saving a space. We can see that if we check directly the csv file. Also, we can see that in the column optionPrice most of the values are 0, which taking into account that it might or not exist that 0 it's consider as a nan or null.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Summary statistics and structure

# %%
# general statistics
ds.describe(include='all').T
# Out:
#                      count unique         top  freq  \
# date                  1100    NaN         NaN   NaN
# ticker                1100      5       ABEV3   220
# name                  1100      5    AMBEVS/A   220
# open                1100.0    NaN         NaN   NaN
# close               1100.0    NaN         NaN   NaN
# min                 1100.0    NaN         NaN   NaN
# max                 1100.0    NaN         NaN   NaN
# avg                 1100.0    NaN         NaN   NaN
# quantity            1100.0    NaN         NaN   NaN
# volume              1100.0    NaN         NaN   NaN
# currency              1100      1          R$  1100
# marketType          1100.0    NaN         NaN   NaN
# bdiCode             1100.0    NaN         NaN   NaN
# prazoT                 0.0    NaN         NaN   NaN
# paperSpecification    1100      9  PN      N1   233
# optionPrice         1100.0    NaN         NaN   NaN
# priceCorrection     1100.0    NaN         NaN   NaN
# paperDueDate        1100.0    NaN         NaN   NaN
# quoteFactor         1100.0    NaN         NaN   NaN
#
#                                              mean                  min  \
# date                2023-06-09 21:09:49.090908928  2023-01-02 00:00:00
# ticker                                        NaN                  NaN
# name                                          NaN                  NaN
# open                                    31.710518                 12.4
# close                                     31.6934                12.29
# min                                     31.345764                12.28
# max                                     32.058736                12.49
# avg                                       31.6924                12.35
# quantity                          37541741.454545            5236900.0
# volume                          1083161210.711818           77286334.0
# currency                                      NaN                  NaN
# marketType                                   10.0                 10.0
# bdiCode                                       2.0                  2.0
# prazoT                                        NaN                  NaN
# paperSpecification                            NaN                  NaN
# optionPrice                                   0.0                  0.0
# priceCorrection                               0.0                  0.0
# paperDueDate                           99991231.0           99991231.0
# quoteFactor                                   1.0                  1.0
#
#                                     25%                  50%  \
# date                2023-03-21 18:00:00  2023-06-12 12:00:00
# ticker                              NaN                  NaN
# name                                NaN                  NaN
# open                              14.67               25.585
# close                             14.65                25.62
# min                               14.47                25.24
# max                               14.84                25.94
# avg                             14.6575               25.565
# quantity                     22629100.0           31335650.0
# volume                      481841623.5          854746320.5
# currency                            NaN                  NaN
# marketType                         10.0                 10.0
# bdiCode                             2.0                  2.0
# prazoT                              NaN                  NaN
# paperSpecification                  NaN                  NaN
# optionPrice                         0.0                  0.0
# priceCorrection                     0.0                  0.0
# paperDueDate                 99991231.0           99991231.0
# quoteFactor                         1.0                  1.0
#
#                                     75%                  max              std
# date                2023-08-28 06:00:00  2023-11-17 00:00:00              NaN
# ticker                              NaN                  NaN              NaN
# name                                NaN                  NaN              NaN
# open                              32.27                97.85        22.567197
# close                           32.2525                 98.0        22.519254
# min                              31.865                96.39        22.330667
# max                             32.5475                98.29         22.75327
# avg                              32.195                97.41         22.53171
# quantity                     44347850.0          237891100.0  23052024.414042
# volume                     1490788166.0         6619016682.0  781159851.46739
# currency                            NaN                  NaN              NaN
# marketType                         10.0                 10.0              0.0
# bdiCode                             2.0                  2.0              0.0
# prazoT                              NaN                  NaN              NaN
# paperSpecification                  NaN                  NaN              NaN
# optionPrice                         0.0                  0.0              0.0
# priceCorrection                     0.0                  0.0              0.0
# paperDueDate                 99991231.0           99991231.0              0.0
# quoteFactor                         1.0                  1.0              0.0

# %%
# pre-stock summary
# to identify which stocks are more volatile or liquid
ds.groupby('ticker')[['open', 'close', 'min', 'max', 'avg', 'volume']].agg(['mean', 'std', 'min', 'max'])
# Out:
#              open                              close                          \
#              mean       std    min    max       mean       std    min    max
# ticker
# ABEV3   14.058318  0.769417  12.40  15.55  14.047682  0.764322  12.29  15.55
# BBDC4   14.799864  1.191485  12.68  17.29  14.804545  1.184420  12.57  17.29
# ITUB4   26.724000  1.547882  23.16  30.29  26.733455  1.558047  23.15  30.45
# PETR4   28.901000  4.128425  21.96  38.69  28.947273  4.133470  22.34  38.52
# VALE3   74.069409  9.928057  61.20  97.85  73.934045  9.965381  61.05  98.00
#
#               min            ...    max               avg                   \
#              mean       std  ...    min    max       mean       std    min
# ticker                       ...
# ABEV3   13.902591  0.752204  ...  12.49  15.78  14.048091  0.759511  12.35
# BBDC4   14.612000  1.188160  ...  12.83  17.50  14.795773  1.182594  12.61
# ITUB4   26.423182  1.562804  ...  23.42  30.59  26.719909  1.551776  23.15
# PETR4   28.520091  4.129641  ...  22.99  38.86  28.925364  4.121950  22.43
# VALE3   73.270955  9.791080  ...  61.74  98.29  73.972864  9.920454  61.29
#
#                      volume
#           max          mean           std          min           max
# ticker
# ABEV3   15.50  3.899219e+08  2.187804e+08   77286334.0  1.796021e+09
# BBDC4   17.28  6.632246e+08  3.860792e+08  180641822.0  3.045812e+09
# ITUB4   30.45  7.863950e+08  3.026186e+08  235561217.0  2.766218e+09
# PETR4   38.30  1.687528e+09  6.782690e+08  479674722.0  3.765606e+09
# VALE3   97.41  1.888737e+09  7.391948e+08  709469874.0  6.619017e+09
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Price Dynamics
#
# To reveal general uptrends/downtrends and volatility.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
for ticker in ds['ticker'].unique():
    subset = ds[ds['ticker'] == ticker]
    plt.plot(subset['date'], subset['close'], label=ticker)

plt.title("Closing Prices Over Time")
plt.xlabel("Date")
plt.ylabel("Close (R$)")
plt.legend()
plt.show()

# %% [markdown]
# ## Returns & volatility

# %%
# Daily returns
ds = ds.sort_values(['ticker', 'date'])
ds['return'] = ds.groupby('ticker')['close'].pct_change()

# %%
ds.groupby('ticker')['return'].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# ticker
# ABEV3   219.0 -0.000110  0.012993 -0.048991 -0.006964 -0.000687  0.005835
# BBDC4   219.0  0.000394  0.019404 -0.081884 -0.010144  0.000606  0.011148
# ITUB4   219.0  0.001111  0.015329 -0.039352 -0.009403  0.000401  0.011431
# PETR4   219.0  0.002399  0.022171 -0.091954 -0.010244  0.002994  0.015679
# VALE3   219.0 -0.000695  0.017574 -0.055106 -0.011433 -0.000739  0.009274
#
#              max
# ticker
# ABEV3   0.050000
# BBDC4   0.052352
# ITUB4   0.082688
# PETR4   0.061564
# VALE3   0.058543

# %%
import seaborn as sns

g = sns.FacetGrid(ds, col="ticker", col_wrap=3, height=3.5, sharex=False, sharey=False)
g.map_dataframe(sns.histplot, x="return", bins=40, kde=True)
g.set_titles(col_template="{col_name}")
g.fig.suptitle("Return Distribution by Ticker", y=1.05)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=ds, x='ticker', y='return')
plt.title("Distribution of Daily Returns per Ticker")
plt.show()

# %% [markdown]
# We could consider the data outside the boxplot outliers, but because this is financial return it is normal to have some small daily outliers. We will interpret them as a volatility events and not data errors.

# %%
# volatility per ticker
volatility = ds.groupby('ticker')['return'].std().sort_values(ascending=False)
print(volatility)
volatility.plot(kind='bar', title='Volatility by Stock')
plt.ylabel('Std. Dev. of Daily Return')
plt.show()
# Out:
# ticker
# PETR4    0.022171
# BBDC4    0.019404
# VALE3    0.017574
# ITUB4    0.015329
# ABEV3    0.012993
# Name: return, dtype: float64

# %% [markdown]
# PETR4 (Petrobras) is the most volatile here, price moves the most from day to day.
# ABEV3 (Ambev) is the most stable, price moves less day to day.

# %% [markdown]
# Among the analyzed B3 tickers, PETR4 exhibited the highest daily volatility (2.2%) and the largest range of returns, consistent with its sensitivity to oil price movements. Conversely, ABEV3 showed the lowest volatility (1.3%), reflecting its defensive nature. Average daily returns were modest across all stocks, ranging from -0.07% (VALE3) to +0.24% (PETR4)

# %% [markdown]
# ## Trading activity

# %%
# Daily volume evolution
plt.figure(figsize=(18, 7))
sns.lineplot(data=ds, x='date', y='volume', hue='ticker')
plt.title("Trading Volume Over Time")
plt.show()

# %%
# Share of total volume
ds.groupby('ticker')['volume'].sum().sort_values(ascending=False).plot(kind='bar')
print(ds.groupby('ticker')['volume'].sum())
plt.title("Total Traded Volume by Ticker")
plt.ylabel("Total Volume (R$)")
plt.show()
# Out:
# ticker
# ABEV3    8.578283e+10
# BBDC4    1.459094e+11
# ITUB4    1.730069e+11
# PETR4    3.712561e+11
# VALE3    4.155220e+11
# Name: volume, dtype: float64

# %%
# In percentage
vol_share = ds.groupby('ticker')['volume'].sum()
vol_share = vol_share / vol_share.sum() * 100
vol_share
# Out:
# ticker
# ABEV3     7.199703
# BBDC4    12.246093
# ITUB4    14.520369
# PETR4    31.159312
# VALE3    34.874523
# Name: volume, dtype: float64

# %% [markdown]
# It shows how much money changes hands for each stock, the liquidity. The higher the total volume, the more actively traded the stock is.
# Stocks like VALE3 and PETR4 dominate total trading activity, highly liquid and usually large-cap. ABEV3, while big, trades less frequently, relatively lower liquidity.

# %% [markdown]
# ## Correlation between tickers

# %%
# Correlations between assets
returns_pivot = ds.pivot(index='date', columns='ticker', values='return')
sns.heatmap(returns_pivot.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Returns")
plt.show()

# %% [markdown]
# BBDC4 and ITUB4 are highly correlated, reflecting their exposure to similar market and macroeconomic conditions, both are banks. In contrast, PETR4 (Petrobras) and VALE3 (Vale) show weak correlations with the financial and consumer sectors (0.14–0.27), suggesting their performance is primarily driven by external commodity and energy price dynamics. ABEV3 (Ambev) maintains moderate correlation with the banks (≈0.4), consistent with its position as a domestic consumption-driven company.

# %% [markdown]
# # Exploration data of our Target

# %%
df = ds.copy()

# %%
numeric_cols = ["open","close","min","max","avg","quantity","volume"]
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df = df.sort_values(["ticker", "date"]).reset_index(drop=True)

# %%
df["tomorrow"] = df.groupby("ticker")["close"].shift(-1)
df["target"] = (df["tomorrow"] > df["close"]).astype(int)

df = df.dropna(subset=["tomorrow"])

# %%
print(df.head())
print(df.info())
print(df.describe())
# Out:
#          date ticker      name   open  close    min    max    avg  quantity  \
# 0  2023-01-02  ABEV3  AMBEVS/A  14.40  14.19  14.02  14.45  14.19  14995900
# 1  2023-01-03  ABEV3  AMBEVS/A  14.16  14.17  14.11  14.39  14.26  36363800
# 2  2023-01-04  ABEV3  AMBEVS/A  14.28  14.25  14.08  14.47  14.30  23791800
# 3  2023-01-05  ABEV3  AMBEVS/A  14.27  14.29  14.14  14.41  14.26  31031500
# 4  2023-01-06  ABEV3  AMBEVS/A  14.30  14.32  14.16  14.36  14.27  20889800
#
#         volume  ... marketType  bdiCode  prazoT paperSpecification  \
# 0  212856851.0  ...         10        2                 ON
# 1  518560034.0  ...         10        2                 ON
# 2  340356296.0  ...         10        2                 ON
# 3  442535690.0  ...         10        2                 ON
# 4  298298670.0  ...         10        2                 ON
#
#   optionPrice  priceCorrection  paperDueDate  quoteFactor  tomorrow  target
# 0         0.0                0      99991231            1     14.17       0
# 1         0.0                0      99991231            1     14.25       1
# 2         0.0                0      99991231            1     14.29       1
# 3         0.0                0      99991231            1     14.32       1
# 4         0.0                0      99991231            1     14.40       1
#
# [5 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 1095 entries, 0 to 1098
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                1095 non-null   object
#  1   ticker              1095 non-null   object
#  2   name                1095 non-null   object
#  3   open                1095 non-null   float64
#  4   close               1095 non-null   float64
#  5   min                 1095 non-null   float64
#  6   max                 1095 non-null   float64
#  7   avg                 1095 non-null   float64
#  8   quantity            1095 non-null   int64
#  9   volume              1095 non-null   float64
#  10  currency            1095 non-null   object
#  11  marketType          1095 non-null   int64
#  12  bdiCode             1095 non-null   int64
#  13  prazoT              1095 non-null   object
#  14  paperSpecification  1095 non-null   object
#  15  optionPrice         1095 non-null   float64
#  16  priceCorrection     1095 non-null   int64
#  17  paperDueDate        1095 non-null   int64
#  18  quoteFactor         1095 non-null   int64
#  19  tomorrow            1095 non-null   float64
#  20  target              1095 non-null   int64
# dtypes: float64(8), int64(7), object(6)
# memory usage: 188.2+ KB
# None
#               open        close          min          max          avg  \
# count  1095.000000  1095.000000  1095.000000  1095.000000  1095.000000
# mean     31.700402    31.682475    31.334639    32.048502    31.681553
# std      22.569928    22.521419    22.332101    22.756125    22.533760
# min      12.400000    12.290000    12.280000    12.490000    12.350000
# 25%      14.670000    14.650000    14.470000    14.840000    14.655000
# 50%      25.580000    25.620000    25.240000    25.930000    25.550000
# 75%      32.240000    32.215000    31.850000    32.485000    32.170000
# max      97.850000    98.000000    96.390000    98.290000    97.410000
#
#            quantity        volume  marketType  bdiCode  optionPrice  \
# count  1.095000e+03  1.095000e+03      1095.0   1095.0       1095.0
# mean   3.752526e+07  1.081985e+09        10.0      2.0          0.0
# std    2.305118e+07  7.797415e+08         0.0      0.0          0.0
# min    5.236900e+06  7.728633e+07        10.0      2.0          0.0
# 25%    2.255810e+07  4.792565e+08        10.0      2.0          0.0
# 50%    3.132440e+07  8.549826e+08        10.0      2.0          0.0
# 75%    4.440440e+07  1.487768e+09        10.0      2.0          0.0
# max    2.378911e+08  6.619017e+09        10.0      2.0          0.0
#
#        priceCorrection  paperDueDate  quoteFactor     tomorrow       target
# count           1095.0        1095.0       1095.0  1095.000000  1095.000000
# mean               0.0    99991231.0          1.0    31.686749     0.505936
# std                0.0           0.0          0.0    22.488449     0.500193
# min                0.0    99991231.0          1.0    12.290000     0.000000
# 25%                0.0    99991231.0          1.0    14.650000     0.000000
# 50%                0.0    99991231.0          1.0    25.620000     1.000000
# 75%                0.0    99991231.0          1.0    32.265000     1.000000
# max                0.0    99991231.0          1.0    98.000000     1.000000

# %%
print(df["target"].value_counts(normalize=True))
# Out:
# target
# 1    0.505936
# 0    0.494064
# Name: proportion, dtype: float64

# %%
ticker_stats = df.groupby("ticker")[["open","close","volume"]].describe()
ticker_stats
# Out:
#          open                                                            \
#         count       mean       std    min     25%    50%     75%    max
# ticker
# ABEV3   219.0  14.059909  0.770817  12.40  13.420  14.20  14.660  15.55
# BBDC4   219.0  14.796347  1.193070  12.68  13.840  14.70  15.620  17.29
# ITUB4   219.0  26.707717  1.532427  23.16  25.530  26.95  27.775  30.00
# PETR4   219.0  28.869361  4.111062  21.96  25.640  28.81  32.240  38.69
# VALE3   219.0  74.068676  9.950796  61.20  66.945  69.28  82.000  97.85
#
#         close             ...                volume                \
#         count       mean  ...     75%    max  count          mean
# ticker                    ...
# ABEV3   219.0  14.049726  ...  14.630  15.55  219.0  3.894232e+08
# BBDC4   219.0  14.801689  ...  15.615  17.29  219.0  6.638184e+08
# ITUB4   219.0  26.716484  ...  27.720  30.31  219.0  7.865689e+08
# PETR4   219.0  28.911826  ...  32.215  38.52  219.0  1.680903e+09
# VALE3   219.0  73.932648  ...  81.785  98.00  219.0  1.889212e+09
#
#                                                                              \
#                  std          min           25%           50%           75%
# ticker
# ABEV3   2.191562e+08   77286334.0  2.533898e+08  3.403650e+08  4.514679e+08
# BBDC4   3.868630e+08  180641822.0  4.272642e+08  5.632224e+08  7.546378e+08
# ITUB4   3.033009e+08  235561217.0  5.745757e+08  7.496289e+08  9.324838e+08
# PETR4   6.726514e+08  479674722.0  1.183568e+09  1.496309e+09  1.993807e+09
# VALE3   7.408546e+08  709469874.0  1.396935e+09  1.782778e+09  2.301623e+09
#
#
#                  max
# ticker
# ABEV3   1.796021e+09
# BBDC4   3.045812e+09
# ITUB4   2.766218e+09
# PETR4   3.765606e+09
# VALE3   6.619017e+09
#
# [5 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
corr = df[["open","close","min","max","avg","quantity","volume","target"]].corr()
plt.imshow(corr, cmap="coolwarm", interpolation="none")
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=90)
plt.yticks(range(len(corr)), corr.columns)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Point-Biserial Correlation with Target
#
# To find linear relationships between each numeric feature and the probability of going up.

# %%
from scipy.stats import pointbiserialr

features = numeric_cols
correlations = {}

for f in features:
    r, p = pointbiserialr(df["target"], df[f])
    correlations[f] = (r, p)

pd.DataFrame(correlations, index=["correlation","p_value"]).T.sort_values("correlation", ascending=False)
# Out:
#           correlation   p_value
# quantity     0.053176  0.078602
# volume       0.030711  0.309944
# avg         -0.013954  0.644629
# close       -0.014075  0.641755
# max         -0.014122  0.640650
# min         -0.014271  0.637118
# open        -0.014861  0.623263

# %% [markdown]
# ## Mutual Information to detect non-linear relationships

# %%
from sklearn.feature_selection import mutual_info_classif

X = df[features]
y = df["target"]

mi = mutual_info_classif(X, y, discrete_features=False, random_state=42)

mi_df = pd.DataFrame({"feature": features, "mutual_information": mi})
mi_df.sort_values("mutual_information", ascending=False)
# Out:
#     feature  mutual_information
# 2       min            0.014086
# 5  quantity            0.012104
# 4       avg            0.002183
# 1     close            0.000000
# 0      open            0.000000
# 3       max            0.000000
# 6    volume            0.000000

# %% [markdown]
# ## Logistic Regression Feature Importance

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

logreg = LogisticRegression()
logreg.fit(X_scaled, y)

coef_df = pd.DataFrame({
    "feature": features,
    "coefficient": logreg.coef_[0]
}).sort_values("coefficient", ascending=False)

coef_df
# Out:
#     feature  coefficient
# 4       avg     0.144498
# 2       min     0.084851
# 1     close     0.072946
# 5  quantity     0.066856
# 6    volume     0.055182
# 3       max    -0.042841
# 0      open    -0.308061

# %%
up = df[df["target"] == 1]
down = df[df["target"] == 0]

plt.figure(figsize=(10,4))
plt.hist(up["close"], bins=30, alpha=0.6, label="Up Tomorrow")
plt.hist(down["close"], bins=30, alpha=0.6, label="Down Tomorrow")
plt.legend()
plt.title("Close Price Distribution – Up vs Down Target")
plt.show()

# %% [markdown]
# ## Feature Distributions by Target

# %%
sns.set(style="whitegrid")

for f in features:
    plt.figure(figsize=(8,4))
    sns.histplot(data=df, x=f, hue="target", kde=False, bins=40, palette="Set2")
    plt.title(f"Histogram of {f} by Target")
    plt.xlabel(f)
    plt.ylabel("Count")
    plt.show()

# %%
for f in features:
    plt.figure(figsize=(8,4))
    sns.kdeplot(data=df, x=f, hue="target", fill=True, common_norm=False, alpha=0.5)
    plt.title(f"KDE Density of {f} by Target")
    plt.xlabel(f)
    plt.show()

# %%
for f in features:
    plt.figure(figsize=(6,4))
    sns.boxplot(data=df, x="target", y=f, palette="Set3")
    plt.title(f"Boxplot of {f} by Target")
    plt.xlabel("Target")
    plt.ylabel(f)
    plt.show()
# Out:
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")
# /tmp/ipykernel_57894/2744140329.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y=f, palette="Set3")

# %%
for f in features:
    plt.figure(figsize=(6,4))
    sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
    plt.title(f"Violin Plot of {f} by Target")
    plt.xlabel("Target")
    plt.ylabel(f)
    plt.show()
# Out:
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)
# /tmp/ipykernel_57894/1053213528.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="target", y=f, palette="Set2", cut=0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('../data/2019-2023_stock_with_features_dif_tickers.csv', low_memory=False)

# List of features you’re using in your model
features = [
    'quantity', 'volume', 'ibovespa_close', 'day_of_week', 'price_range',
    'volume_per_quantity', 'rolling_std_5', 'rolling_return_5', 'momentum_5',
    'rolling_volume_5', 'Trend_2', 'Close_Ratio_5', 'Trend_5',
    'Close_Ratio_55', 'Trend_55', 'Close_Ratio_220'
]

# Keep only the numeric columns you care about
df_features = df[features].copy()

corr_matrix = df_features.corr()
print(corr_matrix.round(2))

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0, annot=True, fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap", fontsize=14)
plt.show()
# Out:
#                      quantity  volume  ibovespa_close  day_of_week  \
# quantity                 1.00    0.58           -0.02         0.03
# volume                   0.58    1.00            0.02         0.03
# ibovespa_close          -0.02    0.02            1.00         0.01
# day_of_week              0.03    0.03            0.01         1.00
# price_range             -0.12    0.22           -0.25         0.02
# volume_per_quantity     -0.26    0.26            0.06         0.00
# rolling_std_5           -0.03    0.16            0.03        -0.01
# rolling_return_5        -0.02    0.01            0.03         0.01
# momentum_5              -0.02    0.02            0.10         0.00
# rolling_volume_5         0.47    0.86            0.02         0.00
# Trend_2                  0.01    0.03            0.04         0.01
# Close_Ratio_5           -0.03    0.02            0.10         0.00
# Trend_5                  0.00    0.03            0.04         0.00
# Close_Ratio_55          -0.10    0.04            0.27         0.00
# Trend_55                -0.03    0.06            0.13         0.00
# Close_Ratio_220         -0.19    0.06            0.27         0.00
#
#                      price_range  volume_per_quantity  rolling_std_5  \
# quantity                   -0.12                -0.26          -0.03
# volume                      0.22                 0.26           0.16
# ibovespa_close             -0.25                 0.06           0.03
# day_of_week                 0.02                 0.00          -0.01
# price_range                 1.00                 0.65           0.30
# volume_per_quantity         0.65                 1.00           0.30
# rolling_std_5               0.30                 0.30           1.00
# rolling_return_5            0.03                 0.05           0.02
# momentum_5                  0.03                 0.09          -0.16
# rolling_volume_5            0.15                 0.29           0.18
# Trend_2                     0.02                 0.04          -0.00
# Close_Ratio_5               0.03                 0.09          -0.17
# Trend_5                     0.02                 0.06           0.01
# Close_Ratio_55              0.03                 0.22          -0.15
# Trend_55                    0.08                 0.18           0.04
# Close_Ratio_220             0.20                 0.40          -0.00
#
#                      rolling_return_5  momentum_5  rolling_volume_5  Trend_2  \
# quantity                        -0.02       -0.02              0.47     0.01
# volume                           0.01        0.02              0.86     0.03
# ibovespa_close                   0.03        0.10              0.02     0.04
# day_of_week                      0.01        0.00              0.00     0.01
# price_range                      0.03        0.03              0.15     0.02
# volume_per_quantity              0.05        0.09              0.29     0.04
# rolling_std_5                    0.02       -0.16              0.18    -0.00
# rolling_return_5                 1.00        0.17              0.00     0.10
# momentum_5                       0.17        1.00             -0.01     0.38
# rolling_volume_5                 0.00       -0.01              1.00     0.01
# Trend_2                          0.10        0.38              0.01     1.00
# Close_Ratio_5                    0.13        0.97             -0.01     0.40
# Trend_5                          0.34        0.36              0.02     0.61
# Close_Ratio_55                   0.25        0.47              0.02     0.22
# Trend_55                         0.14        0.10              0.07     0.20
# Close_Ratio_220                  0.16        0.24              0.05     0.12
#
#                      Close_Ratio_5  Trend_5  Close_Ratio_55  Trend_55  \
# quantity                     -0.03     0.00           -0.10     -0.03
# volume                        0.02     0.03            0.04      0.06
# ibovespa_close                0.10     0.04            0.27      0.13
# day_of_week                   0.00     0.00            0.00      0.00
# price_range                   0.03     0.02            0.03      0.08
# volume_per_quantity           0.09     0.06            0.22      0.18
# rolling_std_5                -0.17     0.01           -0.15      0.04
# rolling_return_5              0.13     0.34            0.25      0.14
# momentum_5                    0.97     0.36            0.47      0.10
# rolling_volume_5             -0.01     0.02            0.02      0.07
# Trend_2                       0.40     0.61            0.22      0.20
# Close_Ratio_5                 1.00     0.32            0.47      0.09
# Trend_5                       0.32     1.00            0.28      0.31
# Close_Ratio_55                0.47     0.28            1.00      0.41
# Trend_55                      0.09     0.31            0.41      1.00
# Close_Ratio_220               0.24     0.16            0.65      0.40
#
#                      Close_Ratio_220
# quantity                       -0.19
# volume                          0.06
# ibovespa_close                  0.27
# day_of_week                     0.00
# price_range                     0.20
# volume_per_quantity             0.40
# rolling_std_5                  -0.00
# rolling_return_5                0.16
# momentum_5                      0.24
# rolling_volume_5                0.05
# Trend_2                         0.12
# Close_Ratio_5                   0.24
# Trend_5                         0.16
# Close_Ratio_55                  0.65
# Trend_55                        0.40
# Close_Ratio_220                 1.00

# %% [markdown]
# Price features (avg, min, max, open) are almost perfectly correlated with close. That’s normal because these are all derived from the same price data. Volume/quantity show weaker correlations, they may influence price movements but aren’t deterministically tied to close. Non-numeric features are ignored in correlation unless preprocessed.

# %% [markdown]
# # Conclusion

# %% [markdown]
# After reviewing the dataset’s structure and field definitions, we decided to remove several columns that do not provide meaningful information for our analysis of stock price behavior. The variables currency, marketType, bdiCode, prazoT, paperSpecification, optionPrice, priceCorrection, paperDueDate, and quoteFactor were either constant across all observations, contained redundant information already represented by the ticker, or were relevant only to other types of financial instruments (e.g., options or bonds).
#
# Since our project focuses on analyzing the evolution of prices, returns, and trading volumes of equities traded on B3, these columns do not contribute to the explanatory power of our dataset and were therefore removed to simplify the analysis and reduce noise.

# %%
# Dropping tables
ds.drop(columns=['currency','marketType','bdiCode','prazoT','paperSpecification','optionPrice', 'priceCorrection','paperDueDate', 'quoteFactor'], inplace=True)

# %%
ds.head()
# Out:
#          date ticker      name   open  close    min    max    avg  quantity  \
# 0  2023-01-02  ABEV3  AMBEVS/A  14.40  14.19  14.02  14.45  14.19  14995900
# 7  2023-01-03  ABEV3  AMBEVS/A  14.16  14.17  14.11  14.39  14.26  36363800
# 10 2023-01-04  ABEV3  AMBEVS/A  14.28  14.25  14.08  14.47  14.30  23791800
# 16 2023-01-05  ABEV3  AMBEVS/A  14.27  14.29  14.14  14.41  14.26  31031500
# 20 2023-01-06  ABEV3  AMBEVS/A  14.30  14.32  14.16  14.36  14.27  20889800
#
#          volume    return
# 0   212856851.0       NaN
# 7   518560034.0 -0.001409
# 10  340356296.0  0.005646
# 16  442535690.0  0.002807
# 20  298298670.0  0.002099
